# %% [markdown]
# # 作業1 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# ### 1. 你選的這組資料為何重要
#     ans: 我選擇的是瘧疾細胞影像的資料集，依據世界衛生組織(WHO)統計，全球每年仍有60萬人死於瘧疾，因此如何有效的治療以及預防瘧疾是一項重要的議題。利用機器學習的方式來分辨感染瘧疾的細胞以及未感染瘧疾的細胞，協助提升診斷的正確率，減少延誤治療造成死亡的機會發生。
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     ans: 資料來源: https://ceb.nlm.nih.gov/repositories/malaria-datasets/
# ### 3. 蒐集而來的資料型態為何
#     ans: 這組資料包含兩組圖片，一組為受到感染的細胞影像，一組為未受到感染的細胞影像的圖片。
# ### 4. 這組資料想解決的問題如何評估
#     ans: 資料集內已分成受到感染以及未受到感染細胞的兩組圖片，透過機器學習模組找尋最佳分辨的方式(分類問題)。

# %% [markdown]
# # 作業2 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     ans: 核心問題為如何提升業績，提升業績的關鍵在於如何提升「總載客里程數」所達成的營收數目，以及如何降低「未載客里程數」所需要的營業成本，藉此達成提升營業收入的目的。
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     ans: 所需要的資料包含(1)乘客資料：性別、年齡、職業、乘客數目 (2)載客資料：收費、地點、時間、付款方式 (3)當日消耗的成本：耗油量、等待時間
#     ，於載客過程中搜集乘客個人資料以及載客資料等，並記錄消耗成本的資訊。
# ### 3. 蒐集而來的資料型態為何
#     ans: 主要以結構化的數值資料為主。
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     ans: 用迴歸的方式挑選出較有意義的資料集，建構出相關的模型，藉此達成最佳化營收的效果。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 217.868
# The Mean absolute error is 11.827
